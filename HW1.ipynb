# %% [markdown]
# <a href="https://colab.research.google.com/github/anci123/generative_ai_course/blob/main/HW1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 繪製函數圖形
# ## 繪製愛心函數
# $$
# \begin{align*}
# x &= 16 \sin^3(\theta) \\
# y &= 13 \cos(\theta) - 5 \cos(2\theta) - 2\cos(3\theta) - \cos(4\theta)
# \end{align*}
# $$

# %%
# 定義愛心函數
theta = np.linspace(0, 2 * np.pi, 400)
x = 16 * ( np.sin(theta) ** 3 )
y = 13 * np.cos(theta) - 5* np.cos(2*theta) - 2 * np.cos(3*theta) - np.cos(4*theta)

#
plt.plot(x, y, color='r')

# 設定標題
plt.title("Cartesian Heart Curve")
# Out:
# Text(0.5, 1.0, 'Cartesian Heart Curve')
